# %%
import pandas as pd

# %%
listings_1 = pd.read_csv('Paris_listing_q1_2024.csv') #listings Q1 2024
listings_4 = pd.read_csv('Paris_listing_q2_2023.csv') #listings Q4 2023
listings_3 = pd.read_csv('Paris_listing_q3_2023.csv') #listings Q3 2023
listings_2 = pd.read_csv('Paris_listing_q4_2023.csv') #listings Q2 2023

# %%
listings_1.head()
listings_1.shape
# Out:
# (84397, 18)

# %%
listings_1.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             7
# neighbourhood_group               84397
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                             23480
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       25575
# reviews_per_month                 25575
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           19800
# dtype: int64

# %%
listings_2.head()
# Out:
#      id                                               name  host_id  \
# 0  3109  Rental unit in Paris · ★5.0 · 1 bedroom · 1 be...     3631
# 1  5396  Rental unit in Paris · ★4.59 · Studio · 1 bed ...     7903
# 2  7397  Rental unit in Paris · ★4.73 · 2 bedrooms · 2 ...     2626
# 3  7964  Rental unit in Paris · ★4.80 · 1 bedroom · 1 b...    22155
# 4  9359  Rental unit in Paris · 1 bedroom · 1 bed · 1 bath    28422
#
#     host_name  neighbourhood_group   neighbourhood  latitude  longitude  \
# 0        Anne                  NaN    Observatoire  48.83191    2.31870
# 1      Borzou                  NaN  Hôtel-de-Ville  48.85247    2.35835
# 2      Franck                  NaN  Hôtel-de-Ville  48.85909    2.35315
# 3       Anaïs                  NaN           Opéra  48.87417    2.34245
# 4  Bernadette                  NaN          Louvre  48.86006    2.34863
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
listings_2.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             9
# neighbourhood_group               74329
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                              7221
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       17891
# reviews_per_month                 17891
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           19642
# dtype: int64

# %%
listings_3.head()
# Out:
#      id                                               name  host_id  \
# 0  3109  Rental unit in Paris · ★5.0 · 1 bedroom · 1 be...     3631
# 1  5396  Rental unit in Paris · ★4.56 · Studio · 1 bed ...     7903
# 2  7397  Rental unit in Paris · ★4.73 · 2 bedrooms · 2 ...     2626
# 3  7964  Rental unit in Paris · ★4.80 · 1 bedroom · 1 b...    22155
# 4  9359  Rental unit in Paris · 1 bedroom · 1 bed · 1 bath    28422
#
#     host_name  neighbourhood_group   neighbourhood  latitude  longitude  \
# 0        Anne                  NaN    Observatoire  48.83191    2.31870
# 1      Borzou                  NaN  Hôtel-de-Ville  48.85247    2.35835
# 2      Franck                  NaN  Hôtel-de-Ville  48.85909    2.35315
# 3       Anaïs                  NaN           Opéra  48.87417    2.34245
# 4  Bernadette                  NaN          Louvre  48.86006    2.34863
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
listings_3.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             7
# neighbourhood_group               67942
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       14757
# reviews_per_month                 14757
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           18570
# dtype: int64

# %%
listings_4.head()
# Out:
#                    id                                               name  \
# 0             1800877  Condo in Paris · ★4.55 · 1 bedroom · 1 bed · 1...
# 1  745443456858903167  Rental unit in Paris · ★4.80 · 1 bedroom · 1 b...
# 2            22687665  Rental unit in Paris · ★4.71 · 1 bedroom · 2 b...
# 3            25037271  Rental unit in Paris · ★4.96 · 1 bedroom · 2 b...
# 4            27106295  Rental unit in Paris · 1 bedroom · 1 bed · 1 p...
#
#      host_id host_name  neighbourhood_group    neighbourhood   latitude  \
# 0    6069249  Stéphane                  NaN  Buttes-Chaumont  48.890460
# 1  178498908  François                  NaN   Hôtel-de-Ville  48.850571
# 2  167168801    Hélène                  NaN  Buttes-Chaumont  48.883470
# 3  189282115   Yannick                  NaN  Buttes-Chaumont  48.885021
# 4  186309131    Coline                  NaN         Entrepôt  48.870180
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
listings_4.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                            18
# neighbourhood_group               61706
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       12281
# reviews_per_month                 12281
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           19378
# dtype: int64

# %%
#Adding a new column to each dataframe to identify the quarter
listings_1['quarter'] = 'Q1_2024'
listings_2['quarter'] = 'Q4_2023'
listings_3['quarter'] = 'Q3_2023'
listings_4['quarter'] = 'Q2_2023'

# %%
listings_1
# Out:
#                         id                                               name  \
# 0                    39948             COSY INDEPENDENT ROOM IN CENTRAL PARIS
# 1                    40143       Stylish & Design 1BR flat- Voltaire Bastille
# 2                    40899          Lovely flat Canal Saint Martin Long stays
# 3                     3109                                       zen and calm
# 4                     5396       Your perfect Paris studio on Île Saint-Louis
# ...                    ...                                                ...
# 84392  1112562855977040914  Artists neighbour apt /private yard 10mn Print...
# 84393  1112591023192990750  Appartement Tour Eiffel - Porte Dauphine - 2 Pers
# 84394  1112842648117310093       1621: Prime spot in Paris Olympic Games 2024
# 84395  1112843324939236177              Stylish flat in the heart of the city
# 84396  1112849968490989659   1637: Prime location in Paris Olympic Games 2024
#
# ...

# %%
listings_2
# Out:
#                         id                                               name  \
# 0                     3109  Rental unit in Paris · ★5.0 · 1 bedroom · 1 be...
# 1                     5396  Rental unit in Paris · ★4.59 · Studio · 1 bed ...
# 2                     7397  Rental unit in Paris · ★4.73 · 2 bedrooms · 2 ...
# 3                     7964  Rental unit in Paris · ★4.80 · 1 bedroom · 1 b...
# 4                     9359  Rental unit in Paris · 1 bedroom · 1 bed · 1 bath
# ...                    ...                                                ...
# 74324  1043629451440755792  Rental unit in Paris · ★New · Studio · 1 bed ·...
# 74325  1043707020977346344  Rental unit in Paris · ★New · 1 bedroom · 1 be...
# 74326  1043932119757241230  Rental unit in Paris · ★New · 3 bedrooms · 4 b...
# 74327  1043947326757240041  Rental unit in Paris · ★New · 1 bedroom · 2 be...
# 74328  1043968453109441641  Rental unit in Paris · ★New · 2 bedrooms · 3 b...
#
# ...

# %%
listings_df = pd.concat([listings_1, listings_2, listings_3,listings_4],ignore_index=True, axis=0)
listings_df
listings_df.shape
listings_df.head()
# Out:
#       id                                          name  host_id  \
# 0  39948        COSY INDEPENDENT ROOM IN CENTRAL PARIS   171483
# 1  40143  Stylish & Design 1BR flat- Voltaire Bastille   172322
# 2  40899     Lovely flat Canal Saint Martin Long stays   177130
# 3   3109                                  zen and calm     3631
# 4   5396  Your perfect Paris studio on Île Saint-Louis     7903
#
#            host_name  neighbourhood_group   neighbourhood  latitude  \
# 0  Aliyah & Philippe                  NaN          Bourse  48.87068
# 1         Emmanuelle                  NaN      Popincourt  48.85719
# 2               Lola                  NaN        Entrepôt  48.87438
# 3               Anne                  NaN    Observatoire  48.83191
# 4             Borzou                  NaN  Hôtel-de-Ville  48.85247
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0    2.34460     Private room    NaN               5                126
# ...

# %%
columns_to_remove = ['last_review',
                   'number_of_reviews_ltm',
                   'license',
                   'neighbourhood_group']
listings_df.drop(columns=columns_to_remove, inplace=True)

# %%
listings_df
# Out:
#                         id                                               name  \
# 0                    39948             COSY INDEPENDENT ROOM IN CENTRAL PARIS
# 1                    40143       Stylish & Design 1BR flat- Voltaire Bastille
# 2                    40899          Lovely flat Canal Saint Martin Long stays
# 3                     3109                                       zen and calm
# 4                     5396       Your perfect Paris studio on Île Saint-Louis
# ...                    ...                                                ...
# 288369             2404876  Rental unit in Paris · ★4.77 · 3 bedrooms · 3 ...
# 288370  876625296659823798  Rental unit in Paris · ★New · 1 bedroom · 1 be...
# 288371  574584027642384480  Condo in Paris · ★5.0 · 4 bedrooms · 3 beds · ...
# 288372            50718612  Hostel in Paris · ★4.96 · 1 bedroom · 6 beds ·...
# 288373  893900838665539285  Rental unit in Paris · ★New · 1 bedroom · 1 be...
#
# ...

# %%
listings_df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                            41
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                             30701
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 70504
# calculated_host_listings_count        0
# availability_365                      0
# quarter                               0
# dtype: int64

# %%
listings_df['price'].mean().round(2)
# Out:
# 227.34

# %%
listings_df['price'] = listings_df['price'].fillna(listings_df['price'].mean()).round(2)

# %%
listings_df
# Out:
#                         id                                               name  \
# 0                    39948             COSY INDEPENDENT ROOM IN CENTRAL PARIS
# 1                    40143       Stylish & Design 1BR flat- Voltaire Bastille
# 2                    40899          Lovely flat Canal Saint Martin Long stays
# 3                     3109                                       zen and calm
# 4                     5396       Your perfect Paris studio on Île Saint-Louis
# ...                    ...                                                ...
# 288369             2404876  Rental unit in Paris · ★4.77 · 3 bedrooms · 3 ...
# 288370  876625296659823798  Rental unit in Paris · ★New · 1 bedroom · 1 be...
# 288371  574584027642384480  Condo in Paris · ★5.0 · 4 bedrooms · 3 beds · ...
# 288372            50718612  Hostel in Paris · ★4.96 · 1 bedroom · 6 beds ·...
# 288373  893900838665539285  Rental unit in Paris · ★New · 1 bedroom · 1 be...
#
# ...
