# %%
import pandas as pd
import seaborn as sns

# %%
#importing the data
madrid_listing_1 = pd.read_csv('madrid_listing_Q1_24.csv')
madrid_listing_2 = pd.read_csv('rome_listing_Q4_23.csv')
madrid_listing_3 = pd.read_csv('rome_listing_Q3_23.csv')
madrid_listing_4 = pd.read_csv('rome_listing_Q2_23.csv')

# %%
#checking the data
madrid_listing_1.info()

# %%
madrid_listing_2.info()

# %%
madrid_listing_3.info()

# %%
madrid_listing_4.info()

# %%
#checking for missing values
madrid_listing_1.isnull().sum()

# %%
madrid_listing_2.isnull().sum()

# %%
madrid_listing_3.isnull().sum()

# %%
madrid_listing_4.isnull().sum()

# %%
#adding a column for the quarter
madrid_listing_1['quarter'] = 'Q1_2024'
madrid_listing_2['quarter'] = 'Q4_2023'
madrid_listing_3['quarter'] = 'Q3_2023'
madrid_listing_4['quarter'] = 'Q2_2023'

# %%
#concatenating the data
madrid_df = pd.concat([madrid_listing_1, madrid_listing_2, madrid_listing_3, madrid_listing_4 ],ignore_index=True, axis=0)

# %%
madrid_df.head(10)

# %%
#removing unnecessary columns
columns_to_remove = ['last_review',
                   'number_of_reviews_ltm',
                   'license',
                   'neighbourhood_group']
                    #host name
madrid_df.drop(columns=columns_to_remove, inplace=True)

# %%
madrid_df

# %%
madrid_df.isnull().sum()

# %%
#fill missing price values with mean
madrid_df['price'] = madrid_df['price'].fillna(madrid_df['price'].mean())

# %%
madrid_df.isnull().sum()

# %%
madrid_df
# Out:
#                         id                                               name  \
# 0                    21853                               Bright and airy room
# 1                   204570                 Lovely 110m2 home - Best location!
# 2                    24805                             Gran Via Studio Madrid
# 3                   205199                                    Tafari Gran Via
# 4                   209373                  Attic in the Heart of Madrid-WIFI
# ...                    ...                                                ...
# 109646  907665329364448150  Rental unit in Rome · ★New · 2 bedrooms · 4 be...
# 109647  907740873805877631  Rental unit in Rome · ★New · 2 bedrooms · 3 be...
# 109648  907795429693803226  Rental unit in Rome · ★New · 1 bedroom · 1 bed...
# 109649  907797510485153442  Rental unit in Rome · ★New · 2 bedrooms · 3 be...
# 109650  907814739994769462  Rental unit in Rome · ★New · 3 bedrooms · 3 be...
#
#           host_id host_name     neighbourhood   latitude  longitude  \
# 0           83531     Abdel          Cármenes  40.403810  -3.741300
# 1         1004721      Alex            Cortes  40.415200  -3.696680
# 2       346366726    Alvaro       Universidad  40.421830  -3.705290
# 3         1008659     Nuria       Universidad  40.421160  -3.703840
# 4         1031664      José       Embajadores  40.411260  -3.703470
# ...           ...       ...               ...        ...        ...
# 109646     494485   Massimo   XII Monte Verde  41.858597  12.439723
# 109647  255338453     Laura  I Centro Storico  41.894868  12.491906
# 109648  465355743   Lorenzo   XIV Monte Mario  41.911356  12.444160
# 109649  507258639  Evgeniia  I Centro Storico  41.898956  12.501748
# 109650  518536799     Yulia  I Centro Storico  41.902406  12.494048
#
#               room_type  price  minimum_nights  number_of_reviews  \
# 0          Private room   31.0               4                 33
# 1       Entire home/apt  180.0               6                103
# 2       Entire home/apt   92.0               5                 35
# 3       Entire home/apt   65.0               7                333
# 4          Private room   32.0               1                 77
# ...                 ...    ...             ...                ...
# 109646  Entire home/apt  112.0              30                  0
# 109647  Entire home/apt  512.0               1                  0
# 109648  Entire home/apt  200.0               4                  0
# 109649  Entire home/apt  128.0               1                  0
# 109650  Entire home/apt  376.0               4                  0
#
#         reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                    0.29                               2               233
# 1                    0.68                               1                10
# 2                    0.31                               1                91
# 3                    2.18                               4               334
# 4                    0.52                               1               174
# ...                   ...                             ...               ...
# 109646                NaN                              25               365
# 109647                NaN                               2               144
# 109648                NaN                               2               349
# 109649                NaN                               2               307
# 109650                NaN                               1               343
#
#         quarter
# 0       Q1_2024
# 1       Q1_2024
# 2       Q1_2024
# 3       Q1_2024
# 4       Q1_2024
# ...         ...
# 109646  Q2_2023
# 109647  Q2_2023
# 109648  Q2_2023
# 109649  Q2_2023
# 109650  Q2_2023
#
# [109651 rows x 15 columns]
