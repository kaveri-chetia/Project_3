# %%
import pandas as pd

df = pd.read_csv('Paris Listing.csv')

# %%
df.head(100)
# Out:
#        id                                          name  host_id  \
# 0   39948        COSY INDEPENDENT ROOM IN CENTRAL PARIS   171483
# 1   40143  Stylish & Design 1BR flat- Voltaire Bastille   172322
# 2   40899     Lovely flat Canal Saint Martin Long stays   177130
# 3    3109                                  zen and calm     3631
# 4    5396  Your perfect Paris studio on Île Saint-Louis     7903
# ..    ...                                           ...      ...
# 95  25450            PARIS 10eme Luxury 2 Bed Apartment   105570
# 96  75708  Studio 30m2 Paris 20e Gambetta/Père Lachaise   402348
# 97  26562            The Eiffel Tower as your neighbour   107514
# 98  77482    House Loft in Paris Batignolles Montmartre   396472
# 99  26827                    UN LOFT A PARIS BELLEVILLE   114407
#
#             host_name  neighbourhood_group        neighbourhood   latitude  \
# 0   Aliyah & Philippe                  NaN               Bourse  48.870680
# ...
